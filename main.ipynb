# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
import os
import sys

os.environ["JAVA_HOME"] = r"C:\Program Files\Zulu\zulu-8"
#os.environ["SPARK_HOME"] = r"C:\spark"
os.environ["PYSPARK_PYTHON"] = sys.executable

# %%
spark = (
    SparkSession.builder
    .master('local[1]')
    .appName('PySpark_01')
    .config("spark.driver.memory", "2g")
    .config("spark.sql.shuffle.partitions", "1")
    .getOrCreate()
)

# %%
df = spark.read.csv('amazon.csv', header=True, inferSchema=True)

# %%
df.show(5)
# Out:
# +----------+--------------------+--------------------+----------------+------------+-------------------+------+------------+---------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |product_id|        product_name|            category|discounted_price|actual_price|discount_percentage|rating|rating_count|        about_product|             user_id|           user_name|           review_id|        review_title|      review_content|            img_link|        product_link|
# +----------+--------------------+--------------------+----------------+------------+-------------------+------+------------+---------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |B07JW9H4J1|Wayona Nylon Brai...|Computers&Accesso...|            ₹399|      ₹1,099|                64%|   4.2|      24,269| High Compatibilit...|AG3D6O4STAQKAY2UV...|Manav,Adarsh gupt...|R3HXWT0LRP0NMF,R2...|Satisfied,Chargin...|Looks durable Cha...|https://m.media-a...|https://www.amazo...|
# |B098NS6PVG|Ambrane Unbreakab...|Computers&Accesso...|            ₹199|        ₹349|                43%|   4.0|      43,994| Compatible with a...|AECPFYFQVRUWC3KGN...|ArdKn,Nirbhay kum...|RGIQEG07R9HS2,R1S...|A Good Braided Ca...|I ordered this ca...|https://m.media-a...|https://www.amazo...|
# |B096MSW6CT|Sounce Fast Phone...|Computers&Accesso...|            ₹199|      ₹1,899|                90%|   3.9|       7,928|【 Fast Charger& D...|AGU3BBQ2V2DDAMOAK...|Kunal,Himanshu,vi...|R3J3EQQ9TZI5ZJ,R3...|Good speed for ea...|Not quite durable...|https://m.media-a...|https://www.amazo...|
# |B08HDJ86NZ|boAt Deuce USB 30...|Computers&Accesso...|            ₹329|        ₹699|                53%|   4.2|      94,363| The boAt Deuce US...|AEWAZDZZJLQUYVOVG...|Omkar dhale,JD,HE...|R3EEUZKKK9J36I,R3...|Good product,Good...|Good product,long...|https://m.media-a...|https://www.amazo...|
# |B08CF3B7N1|Portronics Konnec...|Computers&Accesso...|            ₹154|        ₹399|                61%|   4.2|      16,905| [CHARGE & SYNC FU...|AE3Q6KSUK5P75D5HF...|rahuls6099,Swasat...|R1BP4L2HH9TFUP,R1...|As good as origin...|Bought this inste...|https://m.media-a...|https://www.amazo...|
# +----------+--------------------+--------------------+----------------+------------+-------------------+------+------------+---------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- product_id: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- discounted_price: string (nullable = true)
#  |-- actual_price: string (nullable = true)
#  |-- discount_percentage: string (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- rating_count: string (nullable = true)
#  |-- about_product: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- review_title: string (nullable = true)
#  |-- review_content: string (nullable = true)
#  |-- img_link: string (nullable = true)
#  |-- product_link: string (nullable = true)

# %%
df.toPandas().isna().sum() #Obs: It works just for small datasets
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Null values counting for large datasets

for coluna in df.columns:
    print(coluna, df.filter(df[coluna].isNull()).count())
# Out:
# product_id 0
# product_name 0
# category 0
# discounted_price 0
# actual_price 0
# discount_percentage 0
# rating 0
# rating_count 2
# about_product 0
# user_id 0
# user_name 0
# review_id 0
# review_title 0
# review_content 0
# img_link 0
# product_link 0

# %%
df = df.withColumnRenamed('img_link', 'image_link')

# %%
# The "\" indicates that the 'enter' will be ignored

df = df.withColumnRenamed('product_id', 'product_ID')\
.withColumnRenamed('user_id', 'user_ID')\
.withColumnRenamed('review_id', 'review_ID')

# %%
# Selecting columns

df.select('product_name', 'category', 'user_name').show(10)
# Out:
# +--------------------+--------------------+--------------------+
# |        product_name|            category|           user_name|
# +--------------------+--------------------+--------------------+
# |Wayona Nylon Brai...|Computers&Accesso...|Manav,Adarsh gupt...|
# |Ambrane Unbreakab...|Computers&Accesso...|ArdKn,Nirbhay kum...|
# |Sounce Fast Phone...|Computers&Accesso...|Kunal,Himanshu,vi...|
# |boAt Deuce USB 30...|Computers&Accesso...|Omkar dhale,JD,HE...|
# |Portronics Konnec...|Computers&Accesso...|rahuls6099,Swasat...|
# |pTron Solero TB30...|Computers&Accesso...|Jayesh,Rajesh k.,...|
# |boAt Micro USB 55...|Computers&Accesso...|Vivek kumar,Amazo...|
# |MI Usb Type-C Cab...|Computers&Accesso...|Pavan A H,Jayesh ...|
# |TP-Link USB WiFi ...|Computers&Accesso...|Azhar JuMan,Aniru...|
# |Ambrane Unbreakab...|Computers&Accesso...|ArdKn,Nirbhay kum...|
# +--------------------+--------------------+--------------------+
# only showing top 10 rows

# %%
df.select(col('product_name').alias('Product Name'), col('category').alias('Category Name'), col('user_name').alias('User Name')).show(10)
# Out:
# +--------------------+--------------------+--------------------+
# |        Product Name|       Category Name|           User Name|
# +--------------------+--------------------+--------------------+
# |Wayona Nylon Brai...|Computers&Accesso...|Manav,Adarsh gupt...|
# |Ambrane Unbreakab...|Computers&Accesso...|ArdKn,Nirbhay kum...|
# |Sounce Fast Phone...|Computers&Accesso...|Kunal,Himanshu,vi...|
# |boAt Deuce USB 30...|Computers&Accesso...|Omkar dhale,JD,HE...|
# |Portronics Konnec...|Computers&Accesso...|rahuls6099,Swasat...|
# |pTron Solero TB30...|Computers&Accesso...|Jayesh,Rajesh k.,...|
# |boAt Micro USB 55...|Computers&Accesso...|Vivek kumar,Amazo...|
# |MI Usb Type-C Cab...|Computers&Accesso...|Pavan A H,Jayesh ...|
# |TP-Link USB WiFi ...|Computers&Accesso...|Azhar JuMan,Aniru...|
# |Ambrane Unbreakab...|Computers&Accesso...|ArdKn,Nirbhay kum...|
# +--------------------+--------------------+--------------------+
# only showing top 10 rows

# %%
df.select(df['product_name'].alias('Name of the product')).show()
# Out:
# +--------------------+
# | Name of the product|
# +--------------------+
# |Wayona Nylon Brai...|
# |Ambrane Unbreakab...|
# |Sounce Fast Phone...|
# |boAt Deuce USB 30...|
# |Portronics Konnec...|
# |pTron Solero TB30...|
# |boAt Micro USB 55...|
# |MI Usb Type-C Cab...|
# |TP-Link USB WiFi ...|
# |Ambrane Unbreakab...|
# |Portronics Konnec...|
# |boAt Rugged v3 Ex...|
# |AmazonBasics Flex...|
# |Portronics Konnec...|
# |Portronics Konnec...|
# |MI Braided USB Ty...|
# |MI 80 cm (32 inch...|
# |Ambrane Unbreakab...|
# |boAt Type C A325 ...|
# |LG 80 cm (32 inch...|
# +--------------------+
# only showing top 20 rows

# %%
# Filtering data

df.filter('rating = 4.2').show(5)
# Out:
# +----------+--------------------+--------------------+----------------+------------+-------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+
# |product_ID|        product_name|            category|discounted_price|actual_price|discount_percentage|rating|rating_count|       about_product|             user_ID|           user_name|           review_ID|        review_title|      review_content|          image_link|        product_link|current_year|
# +----------+--------------------+--------------------+----------------+------------+-------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+
# |B07JW9H4J1|Wayona Nylon Brai...|Computers&Accesso...|            ₹399|      ₹1,099|                64%|   4.2|      24,269|High Compatibilit...|AG3D6O4STAQKAY2UV...|Manav,Adarsh gupt...|R3HXWT0LRP0NMF,R2...|Satisfied,Chargin...|Looks durable Cha...|https://m.media-a...|https://www.amazo...|        2025|
# |B08HDJ86NZ|boAt Deuce USB 30...|Computers&Accesso...|            ₹329|        ₹699|                53%|   4.2|      94,363|The boAt Deuce US...|AEWAZDZZJLQUYVOVG...|Omkar dhale,JD,HE...|R3EEUZKKK9J36I,R3...|Good product,Good...|Good product,long...|https://m.media-a...|https://www.amazo...|        2025|
# |B08CF3B7N1|Portronics Konnec...|Computers&Accesso...|            ₹154|        ₹399|                61%|   4.2|      16,905|[CHARGE & SYNC FU...|AE3Q6KSUK5P75D5HF...|rahuls6099,Swasat...|R1BP4L2HH9TFUP,R1...|As good as origin...|Bought this inste...|https://m.media-a...|https://www.amazo...|        2025|
# |B008IFXQFU|TP-Link USB WiFi ...|Computers&Accesso...|            ₹499|        ₹999|                50%|   4.2|    1,79,691|USB WiFi Adapter ...|AGV3IEFANZCKECFGU...|Azhar JuMan,Aniru...|R1LW6NWSVTVZ2H,R3...|Works on linux fo...|I use this to con...|https://m.media-a...|https://www.amazo...|        2025|
# |B0789LZTCJ|boAt Rugged v3 Ex...|Computers&Accesso...|            ₹299|        ₹799|                63%|   4.2|      94,363|The boAt rugged c...|AEWAZDZZJLQUYVOVG...|Omkar dhale,JD,HE...|R3EEUZKKK9J36I,R3...|Good product,Good...|Good product,long...|https://m.media-a...|https://www.amazo...|        2025|
# +----------+--------------------+--------------------+----------------+------------+-------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+
# only showing top 5 rows

# %%
df.filter((col('rating') == 4.2) | (col('rating') == 4.3)).show(5)
# Out:
# +----------+--------------------+--------------------+----------------+------------+-------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+-------------+------+--------+
# |product_ID|        product_name|            category|discounted_price|actual_price|discount_percentage|rating|rating_count|       about_product|             user_ID|           user_name|           review_ID|        review_title|      review_content|          image_link|        product_link|current_year|status_review| price|quantity|
# +----------+--------------------+--------------------+----------------+------------+-------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+-------------+------+--------+
# |B07JW9H4J1|Wayona Nylon Brai...|Computers&Accesso...|            ₹399|      ₹1,099|                64%|   4.2|      24,269|High Compatibilit...|AG3D6O4STAQKAY2UV...|Manav,Adarsh gupt...|R3HXWT0LRP0NMF,R2...|Satisfied,Chargin...|Looks durable Cha...|https://m.media-a...|https://www.amazo...|        2025|         good|1099.0|       5|
# |B08HDJ86NZ|boAt Deuce USB 30...|Computers&Accesso...|            ₹329|        ₹699|                53%|   4.2|      94,363|The boAt Deuce US...|AEWAZDZZJLQUYVOVG...|Omkar dhale,JD,HE...|R3EEUZKKK9J36I,R3...|Good product,Good...|Good product,long...|https://m.media-a...|https://www.amazo...|        2025|         good| 699.0|       5|
# |B08CF3B7N1|Portronics Konnec...|Computers&Accesso...|            ₹154|        ₹399|                61%|   4.2|      16,905|[CHARGE & SYNC FU...|AE3Q6KSUK5P75D5HF...|rahuls6099,Swasat...|R1BP4L2HH9TFUP,R1...|As good as origin...|Bought this inste...|https://m.media-a...|https://www.amazo...|        2025|         good| 399.0|       5|
# |B08DDRGWTJ|MI Usb Type-C Cab...|Computers&Accesso...|            ₹229|        ₹299|                23%|   4.3|      30,411|1m long Type-C US...|AHW6E5LQ2BDYOIVLA...|Pavan A H,Jayesh ...|R2X090D1YHACKR,R3...|Worth for money -...|Worth for money -...|https://m.media-a...|https://www.amazo...|        2025|         good| 299.0|       5|
# |B008IFXQFU|TP-Link USB WiFi ...|Computers&Accesso...|            ₹499|        ₹999|                50%|   4.2|    1,79,691|USB WiFi Adapter ...|AGV3IEFANZCKECFGU...|Azhar JuMan,Aniru...|R1LW6NWSVTVZ2H,R3...|Works on linux fo...|I use this to con...|https://m.media-a...|https://www.amazo...|        2025|         good| 999.0|       5|
# +----------+--------------------+--------------------+----------------+------------+-------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+-------------+------+--------+
# only showing top 5 rows

# %%
# Creating a new column with literal value

df = df.withColumn("current_year", lit('2025'))

# %%
df = df.withColumn("quantity", lit(5))

# %%
# Casting columns

df = df.withColumn('rating', col('rating').cast("double"))

# %%
df = df.withColumn(
    "price",
    regexp_replace(col('actual_price'), "[₹,]", "").cast('double')
)

# %%
# Creating columns with conditions using when() and otherwise()

df = df.withColumn(
    "status_review",
    when(col('rating') >= 4.5, "excelent")\
    .when(col('rating') >= 4.0, "good")\
    .otherwise("regular")
)

# %%
df = df.withColumn("subtotal", col("price") * col("quantity"))

# %%
# Creating more than one column at the same time
df = df.select(
    "*", 
    length(col("product_name")).alias("product_name_length"),
    when(col("price") >= 100, "expensive").otherwise("cheap").alias("price range")
)

# %%
# Counting values

df.select(col('status_review')).toPandas().count()
# Out:
# status_review    1465
# dtype: int64

# %%
df.select('category').distinct().count()
# Out:
# 243

# %%
df.groupBy('category').count().count()
# Out:
# 243

# %%
# If you want to see a number, use count()
# If you want to see data, use the show() in the end

df.groupBy('category').count().show()
# Out:
# +--------------------+-----+
# |            category|count|
# +--------------------+-----+
# |Computers&Accesso...|  233|
# |Computers&Accesso...|   18|
# |Electronics|HomeT...|   24|
# |Electronics|HomeT...|   63|
# |Electronics|HomeT...|   49|
# |Electronics|HomeT...|    6|
# |Electronics|HomeT...|    6|
# |Electronics|HomeT...|    2|
# |Electronics|HomeA...|    1|
# |Electronics|HomeT...|    3|
# |                  AV|    1|
# |                  PC|    1|
# |Electronics|HomeA...|    1|
# |Electronics|HomeT...|    3|
# |Computers&Accesso...|    1|
# |Electronics|HomeT...|    1|
# |Electronics|HomeA...|    1|
# |Electronics|HomeT...|    1|
# |Electronics|HomeA...|    1|
# |Electronics|HomeT...|    1|
# +--------------------+-----+
# only showing top 20 rows
